# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/gdrive/MyDrive/Vehicle_Counting/road.png")

cv2.putText(img, 'IN 50', (150, 200), cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 255), 5)
cv2.putText(img, 'OUT 50', (800, 200), cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 255), 5)
cv2.putText(img, 'TOTAL 120', (400, 100), cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 255), 5)

cv2.line(img, (380, 400), (880, 400), (0, 255, 0), thickness=10)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F8C8D3747D0>
