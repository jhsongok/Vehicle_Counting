# %%
# 참고 : https://github.com/emasterclassacademy/Single-Multiple-Custom-Object-Detection-and-Tracking

# %%
# !pip uninstall tensorflow -y
# !pip install "tensorflow<=2.3.0"
# Out:
# Found existing installation: tensorflow 2.6.0
# Uninstalling tensorflow-2.6.0:
#   Successfully uninstalled tensorflow-2.6.0
# ...
#      |████████████████████████████████| 320.4 MB 44 kB/s
# ...
#      |████████████████████████████████| 2.9 MB 69.4 MB/s
# ...
#      |████████████████████████████████| 20.1 MB 226 kB/s
# ...
#      |████████████████████████████████| 459 kB 70.0 MB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# clone repository for deepsort with yolov3
# !git clone https://github.com/emasterclassacademy/Single-Multiple-Custom-Object-Detection-and-Tracking.git 'Yolov3_DeepSort'
# Out:
# Cloning into 'Yolov3_DeepSort'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 72 (delta 9), reused 9 (delta 0), pack-reused 0
# Unpacking objects: 100% (72/72), done.

# %%
# step into Yolov3_DeepSort folder
# %cd 'Yolov3_DeepSort'
# Out:
# /content/Yolov3_DeepSort

# %%
# download yolov3 model weights to weights folder
# !wget https://pjreddie.com/media/files/yolov3.weights -P weights/
# Out:
# --2021-09-19 14:31:33--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘weights/yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   105MB/s    in 2.2s
#
# 2021-09-19 14:31:35 (105 MB/s) - ‘weights/yolov3.weights’ saved [248007048/248007048]

# %%
# download yolov3-tiny model weights to weights folder
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights -P weights/
# Out:
# --2021-09-19 14:31:45--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘weights/yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  98.2MB/s    in 0.3s
#
# 2021-09-19 14:31:45 (98.2 MB/s) - ‘weights/yolov3-tiny.weights’ saved [35434956/35434956]

# %%
# Convert Yolo3 weights to tensorflow model
# !python convert.py
# Out:
# 2021-09-19 14:31:57.123651: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-19 14:31:59.568793: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-09-19 14:31:59.622015: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-19 14:31:59.622612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-19 14:31:59.622647: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# Convert Yolo3-tiny weights to tensorflow model
# !python convert.py --weights ./weights/yolov3-tiny.weights --output ./weights/yolov3-tiny.tf --tiny
# Out:
# 2021-09-19 14:32:11.075030: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-19 14:32:12.936355: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-09-19 14:32:12.953459: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-19 14:32:12.954040: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-19 14:32:12.954073: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !rm object_tracker.py
# !cp /content/gdrive/MyDrive/Vehicle_Counting/object_tracker.py .
# !cp '/content/gdrive/MyDrive/Vehicle_Counting/Relaxing highway traffic.mp4' './data/video/'

# %%
# ./tools/generate_detections.py 84,86 line 에서 "net/%s:0" --> "%s:0" 로 수정해 줘야 함.

# !python object_tracker.py
# Out:
# 2021-09-19 14:44:26.588095: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-19 14:44:28.010821: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-09-19 14:44:28.025677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-19 14:44:28.026272: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-19 14:44:28.026306: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# define helper function to display videos
import io 
from IPython.display import HTML
from base64 import b64encode
def show_video(file_name, width=640):
  # show resulting deepsort video
  mp4 = open(file_name,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width="{0}" controls>
        <source src="{1}" type="video/mp4">
  </video>
  """.format(width, data_url))

# %%
# convert resulting video from avi to mp4 file format
import os
path_video = os.path.join("data/video","results.avi")
# %cd data/video
# !ffmpeg -y -loglevel panic -i results.avi results.mp4
# %cd ../../

# output object tracking video
path_output = os.path.join("data/video","results.mp4")
show_video(path_output, width=960)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
